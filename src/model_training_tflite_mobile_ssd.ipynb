# %%
# !pip install tensorflow==2.13.0
# !pip install opencv-python-headless
# !pip install pillow lxml matplotlib pycocotools
# !pip install pandas Cython contextlib2 tf_slim
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.13.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.20.0rc0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\Ajinkya\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for tensorflow==2.13.0
# Requirement already satisfied: opencv-python-headless in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from opencv-python-headless) (1.26.1)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\Ajinkya\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# Requirement already satisfied: pillow in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (10.0.1)
# Collecting lxml
#   Downloading lxml-6.0.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: matplotlib in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (3.8.0)
# Collecting pycocotools
#   Downloading pycocotools-2.0.10-cp312-abi3-win_amd64.whl.metadata (1.3 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Downloading lxml-6.0.0-cp312-cp312-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 1.5 MB/s eta 0:00:03
#    ------- -------------------------------- 0.8/4.0 MB 1.6 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/4.0 MB 1.7 MB/s eta 0:00:02
#    --------------- ------------------------ 1.6/4.0 MB 1.8 MB/s eta 0:00:02
#    -------------------- ------------------- 2.1/4.0 MB 1.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 2.4/4.0 MB 1.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 1.9 MB/s eta 0:00:01
#    --------------------------------- ------ 3.4/4.0 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 1.8 MB/s eta 0:00:00
# Downloading pycocotools-2.0.10-cp312-abi3-win_amd64.whl (76 kB)
# Installing collected packages: pycocotools, lxml
# Successfully installed lxml-6.0.0 pycocotools-2.0.10
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\Ajinkya\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (2.3.1)
# Collecting Cython
#   Downloading cython-3.1.2-cp312-cp312-win_amd64.whl.metadata (6.0 kB)
# Collecting contextlib2
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting tf_slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: absl-py>=0.2.2 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from tf_slim) (2.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\ajinkya\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading cython-3.1.2-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 2.8 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.7 MB 2.3 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.7 MB 2.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.7 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.7 MB 2.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 2.0 MB/s eta 0:00:00
# Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
# Installing collected packages: tf_slim, Cython, contextlib2
# Successfully installed Cython-3.1.2 contextlib2-21.6.0 tf_slim-1.1.0
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\Ajinkya\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# Collecting git+https://github.com/tensorflow/models.git
#   Cloning https://github.com/tensorflow/models.git to c:\users\ajinkya\appdata\local\temp\pip-req-build-aodpsqca
#   Resolved https://github.com/tensorflow/models.git to commit 5f846b08bedd4866ee5da6f93a2c07d521cf2e02
#   Running command git clone --filter=blob:none --quiet https://github.com/tensorflow/models.git 'C:\Users\Ajinkya\AppData\Local\Temp\pip-req-build-aodpsqca'
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\Ajinkya\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# ERROR: git+https://github.com/tensorflow/models.git does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !pip install git+https://github.com/tensorflow/models.git
# Out:
# Collecting git+https://github.com/tensorflow/models.git
#   Cloning https://github.com/tensorflow/models.git to c:\users\ajinkya\appdata\local\temp\pip-req-build-vmyl5w4e
#   Resolved https://github.com/tensorflow/models.git to commit 5f846b08bedd4866ee5da6f93a2c07d521cf2e02
#   Running command git clone --filter=blob:none --quiet https://github.com/tensorflow/models.git 'C:\Users\Ajinkya\AppData\Local\Temp\pip-req-build-vmyl5w4e'
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\Ajinkya\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# ERROR: git+https://github.com/tensorflow/models.git does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
import shutil
shutil.rmtree("models", ignore_errors=True)

# %%
# !rmdir /s /q models
# !git clone https://github.com/tensorflow/models.git
# Out:
# ^C
